# %%
#LV
# FDS aaignment no. 1

# In second year computer engineering class, group A student’s play cricket, group B
# students play badminton and group C students play football.
# Write a Python program using functions to compute following: -
# a) List of students who play both cricket and badminton
# b) List of students who play either cricket or badminton but not both
# c) Number of students who play neither cricket nor badminton
# d) Number of students who play cricket and football but not badminton.

def removedup(lst):
    lst1 = []
    n = len(lst)
    for i in range(n):
        if lst[i] not in lst1:
            lst1.append(lst[i])
    return lst1

def uniom(lst1, lst2):
    n = len(lst1)
    m = len(lst2)
    lst3 = []
    
    for i in range(n):
        if lst1[i] not in lst3:
            lst3.append(lst1[i])
    
    for i in range(m):
        if lst2[i] not in lst3:
            lst3.append(lst2[i])
    return lst3

def intersection(lst1, lst2):
    n = len(lst1)
    m = len(lst2)
    
    lst3 = []
    
    for i in range(n):
        if lst1[i] in lst2:
            lst3.append(lst1[i])
    return lst3

def diff(lst1, lst2):
    n = len(lst1)
    lst3 = []
    
    for i in range(n):
        if lst1[i] not in lst2:
            lst3.append(lst1[i])
    return lst3


lst1 = [4,6,6,7,6,2,5,5,3,1,8,6,2,4,3,4]

lst2 = [1,8,2,2,5,8,1]


# print(uniom(lst1, lst2))
# print(removedup(lst1))
# print(intersection(removedup(lst1), removedup(lst2)))
# print(diff(removedup(lst2), removedup(lst1)))

# %%
#LV
# FDS aaignment no. 2

# Write a Python program to store marks scored in subject “Fundamental of Data Structure” by N students in the class. Write functions to compute following:
# a) The average score of class
# b) Highest score and lowest score of class
# c) Count of students who were absent for the test
# d) Display mark with highest frequency


def average(fds):
    n = len(fds)
    
    s = 0
    cnt = 0
    
    for i in range(n):
        if fds[i] != -999:
            s += fds[i]
            cnt += 1
            
    avg = s / cnt
    return avg

def highest(fds):
    high = fds[0]
    
    n = len(fds)
    
    for i in range(n):
        if fds[i] > high:
            high = fds[i]
    return high

def lowest(fds):
    low = fds[0]
    
    n = len(fds)
    
    for i in range(n):
        if fds[i] < low:
            low = fds[i]
    return low

def absenty(fds):
    n = len(fds)
    cnt = 0
    
    for i in range(n):
        if fds[i] == -999:
            cnt += 1
    return cnt

def freq(fds):
    cnt = 0
    mcnt = float('-inf')
    t = 0
    dup = []
    n = len(fds)
    
    for i in range(n):
        if fds[i] not in dup:
            dup.append(fds[i])
    
    for i in dup:
        for j in fds:
            if i == j:
                cnt += 1
        if mcnt < cnt:
            mcnt = cnt
            f = i
        cnt = 0
                
    if mcnt == 1:
        print("None of the marks appear at higher frequency each marks appeared at once")
    else:
        print(f"Marks: {f} appeared {mcnt} times")
        
fds = [98,98,99,99,1,2,4,5,44,7,5,4,1,2,6,]
freq(fds)
# Out:
# Marks: 98 appeared 2 times

# %%
# LV
# FDS Assignment 3

# Write a Python program to store first year percentage of students in array. Write function for sorting array of floating point numbers in ascending order using
# a) Selection Sort
# b) Bubble sort and display top five scores.

def sel(arr):
    n = len(arr)
    minIdx = 0
    for i in range(n - 1):
        minIdx = i
        for j in range(i + 1, n):
            if arr[minIdx] > arr[j]:
                minIdx = j
                arr[i], arr[minIdx] = arr[minIdx], arr[i]
    return arr

def bubble(arr):
    n = len(arr)
    
    
    for i in range(n - 1):
        for j in range(n - i -1):
            if arr[j] > arr[j + 1]:
                arr[j + 1], arr[j] = arr[j], arr[j + 1]
    return arr

mrk = [12,4556,74,12,3,5,4,5,6,87,4,1,0]
u = sel(mrk)
print(u)
# Out:
# [0, 1, 5, 6, 4, 5, 4, 3, 12, 12, 87, 74, 4556]

# %%
# KR
# Assignment 1 
# Write a Python program to compute following operations on String:
# a) To display word with the longest length
# b) To determines the frequency of occurrence of particular character in the string
# c) To check whether given string is palindrome or not
# d) To display index of first appearance of the substring
# e) To count the occurrences of each word in a given string

def longestWord(s):
    spt = s.split()
    n = len(spt)
    length = 0
    word = ""
    
    for i in range(n):
        if len(spt[i]) > length:
            length = len(spt[i])
            word = spt[i]
    print(f"The longest word is {word} with length {length}")

    
def freq():
    sentence = input("Enter a sentence: ")
    char = input("Enter the character: ")
    cnt = 0
    
    for i in sentence:
        if i == char:
            cnt += 1
    return cnt

def palindrome():
    word = input("Enter the word: ")
    reverse = word[::-1]
    if word == reverse:
        print("Given word is a palindrome")
    else:
        print("Given word is not a palindrome")
        
def subString():
    strr = input("Enter a string: ")
    substr = input("Enter a substring: ")
    
    n = len(strr)
    idx = 0
    j = 0
    
    for i in range(n):
        if strr[i] == substr[j]:
            flag = 1
            j += 1
        if j == len(substr):
            idx = i - (len(substr) - 1)
            break
        else:
            flag = 0
    if flag == 1:
        print(f"Index of first appearance of the substring is {idx}")
    else:
        print(f"substring {substr} not present")

def occur():
    sentence = input("Enter a sentence: ")
    
    spt = sentence.split()
    dup = []
    
    for i in spt:
        if i not in dup:
            dup.append(i)
            
    cnt = 0
    for i in range(len(dup)):
        for j in range(len(spt)):
            if dup[i] == spt[j]:
                cnt += 1
        if cnt == 1:
            print(f"{dup[i]}   occurred   {cnt} time")
        else:
            print(f"{dup[i]}   occurred   {cnt} times")
        cnt = 0

# longestWord(sentence)
# freq()
# palindrome()
# subString()
# occur()

# %%
# KR 
# Assignment 2
# Write a Python program to compute following computation on matrix:
# a) Addition of two matrices B) Subtraction of two matrices
# c) Multiplication of two matrices d) Transpose of a matrix

A = [] #Defined two global list for matrix operation
B = []
 
 
def matrixinput(list):  # taking input for operations
        row = int(input("Enter the no. of rows: "))
        col = int(input("Enter the no. of columns: "))
        for i in range(row):
            a = []
            for j in range(col):
                n = int(input(f"Enter the element for postion[{i}][{j}]: "))
                a.append(n)
            list.append(a)
        return list
    
 
 
def add(): #Matrix addition
    S = []
    for i in range(2):
        s = []
        for j in range(2):
            s1 = A[i][j] + B[i][j]
            s.append(s1)
        S.append(s)
    return S
        
def sub():  #Matrix Substraction
    S = []
    for i in range(2):
        s = []
        for j in range(2):
            s1 = A[i][j] - B[i][j]
            s.append(s1)
        S.append(s)
    return S
 
def mul(): #matrix multiplication
        #input for first matrix 
 
        print("\nEnter the no. of rows and columns for MATRIX 1 ->") 
        row1 = int(input("\nEnter the no. of rows: "))    
        col1 = int(input("Enter the no. of columns: "))
        print("\nEnter the elemnts for MATRIX 1 ->")
        for i in range(row1):
            a = []
            for j in range(col1):
                n = int(input(f"Enter the element for postion[{i}][{j}]: "))
                a.append(n)
            A.append(a)
        print("\nMATRIX 1 -> ", A)
        #input for second matrix
 
        print("\nEnter the no. of rows and columns for MATRIX 2 ->")
        row2 = int(input("\nEnter the no. of rows: "))
        col2 = int(input("Enter the no. of columns: "))
        print("\nEnter the elemnts for MATRIX 1 ->")
        for i in range(row2):
            v = []
            for j in range(col2):
                v1 = int(input(f"Enter the element for postion[{i}][{j}]: "))
                v.append(v1)
            B.append(v)
        print("\nMATRIX 1 -> ", B)
        
        c = 0
        m = []
        if col1 == row2:
            for i in range(row1):
                b =[]
                for j in range(col2):
                    for k in range(col1):
                        c += A[i][k] * B[k][j]
                    b.append(c)
                    c = 0
                m.append(b)
        print("\nThe matrix multiplication is: ",m)
        else:
            print(\n"Plz enter same no. of col of first matrix and rows of second matrix")
 
 
    
 
def transpose():  #matrix transpose
    e = []
    for i in range(2):
        g = []
        for j in range(2):
            g1 = 0
            g.append(g1)
        e.append(g)  
    for i in range(2):
        for j in range(2):
            e[i][j] = A[j][i]
    print("\nThe matrix transpose is: ", e)
 
while(True):
    
    print("\nFor matrix addition press '1'")
    print("For matrix substraction press '2'")
    print("For matrix multiplication press '3'")
    print("For matrix transpose press '4'")
    print("To ESCAPE the 'MATRIX' choices press '5'")
    flag = int(input("Enter your choice here ->> "))
    
    if flag == 1:
        print("\nEnter the elemnts for MATRIX 1 ->")
        print("Matrix 1 : ", matrixinput(A))
        print("Enter the elemnts for MATRIX 2 ->")
        print("Matrix 2 : ", matrixinput(B))
        print("The matrix addition is: ", add())
        
    elif flag == 2:
        print("\nEnter the elemnts for MATRIX 1 ->")
        print("Matrix 1 : ", matrixinput(A))
        print("Enter the elemnts for MATRIX 2 ->")
        print("Matrix 2 : ", matrixinput(B))
        print("The matrix substraction is: ", sub())
        
    elif flag == 3:
        mul()
    
    elif flag == 4:
        print("\nEnter the elemnts for MATRIX  ->")
        print("Matrix  : ", matrixinput(A))
        transpose()  
        
    else:
        print("\nThankyou")
        break

# %%
A = []  # Defined two global lists for matrix operations
B = []

def matrixinput():  # Taking input for a single matrix
    matrix = []
    row = int(input("Enter the number of rows: "))
    col = int(input("Enter the number of columns: "))
    for i in range(row):
        row_data = []
        for j in range(col):
            n = int(input(f"Enter the element for position [{i}][{j}]: "))
            row_data.append(n)
        matrix.append(row_data)
    return matrix

def add():
    if len(A) != len(B) or len(A[0]) != len(B[0]):
        print("Addition not possible. Matrices must have the same dimensions.")
        return
    S = [[A[i][j] + B[i][j] for j in range(len(A[0]))] for i in range(len(A))]
    return S

def sub():
    if len(A) != len(B) or len(A[0]) != len(B[0]):
        print("Subtraction not possible. Matrices must have the same dimensions.")
        return
    S = [[A[i][j] - B[i][j] for j in range(len(A[0]))] for i in range(len(A))]
    return S

def mul():
    if len(A[0]) != len(B):
        print("Multiplication not possible. Columns of the first matrix must equal rows of the second matrix.")
        return
    result = [[sum(A[i][k] * B[k][j] for k in range(len(B))) for j in range(len(B[0]))] for i in range(len(A))]
    return result

def transpose(matrix):
    return [[matrix[j][i] for j in range(len(matrix))] for i in range(len(matrix[0]))]

while True:
    print("\nFor matrix addition press '1'")
    print("For matrix subtraction press '2'")
    print("For matrix multiplication press '3'")
    print("For matrix transpose press '4'")
    print("To exit press '5'")
    choice = int(input("Enter your choice here ->> "))

    if choice == 1:
        print("\nEnter elements for MATRIX 1:")
        A = matrixinput()
        print()
        print("Enter elements for MATRIX 2:")
        B = matrixinput()
        print()
        result = add()
        if result:
            print("The matrix addition is:", result)
            print()

    elif choice == 2:
        print("\nEnter elements for MATRIX 1:")
        A = matrixinput()
        print()
        print("Enter elements for MATRIX 2:")
        B = matrixinput()
        print()
        result = sub()
        if result:
            print("The matrix subtraction is:", result)
            print()

    elif choice == 3:
        print("\nEnter elements for MATRIX 1:")
        A = matrixinput()
        print()
        print("Enter elements for MATRIX 2:")
        B = matrixinput()
        print()
        result = mul()
        if result:
            print("The matrix multiplication is:", result)
            print()

    elif choice == 4:
        print("\nEnter elements for the matrix to transpose:")
        matrix = matrixinput()
        print()
        print("The matrix transpose is:", transpose(matrix))
        print()

    elif choice == 5:
        print("Thank you!")
        break

    else:
        print("Invalid choice, please try again.")

# %%
# KR
# Assignment 3 - 4

# a) Write a Python program to store roll numbers of student in array who attended
# training program in random order. Write function for searching whether particular
# student attended training program or not, using Linear search and Sentinel search.

# b) Write a Python program to store roll numbers of student array who attended training
# program in sorted order. Write function for searching whether particular student
# attended training program or not, using Binary search and Fibonacci search


def linearSearch(arr, k):
    n = len(arr)
    
    flag = 0
    
    for i in range(n):
        if arr[i] == k:
            flag = 1
            
    if flag == 0:
        print("NF, ", k)
    else:
        print("F, ", k)
 

def sentinelSearch(arr, k):
    n = len(arr)
    
    last = arr[n - 1]
    
    arr[n - 1] = k
    
    i = 0
    
    while (arr[i] != k):
        i += 1
        
    arr[n - 1] = last
    
    if i < n - 1 or arr[n - 1] == k:
        print("Found, ",arr[i])
    else:
        print("Not Found, ", k)

        
def binary(arr, k,low, high):
    n = len(arr) 
    
    while (low <= high):
        mid = (low + high) // 2
        if (arr[mid] == k):
            return mid
        elif (arr[mid] > k):
            high = mid - 1
        else:
            low = mid + 1
    return -1
 
    
def fibonacciSearch(arr, k):
    # Get length of array
    n = len(arr)
    
    # Initialize Fibonacci numbers
    fib2 = 0   # (n-2)th Fibonacci number
    fib1 = 1   # (n-1)th Fibonacci number
    fib = fib1 + fib2   # nth Fibonacci number

    # Find the smallest Fibonacci number greater than or equal to n
    while fib < n:
        fib2 = fib1
        fib1 = fib
        fib = fib1 + fib2
        
    # Initialize the offset
    offset = -1
    
    # Main loop for searching
    while fib > 1:
        # Get valid index
        i = min(offset + fib2, n - 1)
        
        # If k is greater than value at index i, cut the subarray from offset to i
        if arr[i] < k:
            fib = fib1
            fib1 = fib2
            fib2 = fib - fib1
            offset = i
                        
        # If k is less than value at index i, cut the subarray after i
        elif arr[i] > k:
            fib = fib2
            fib1 = fib1 - fib2
            fib2 = fib - fib1
            
        # Element found
        else:
            return i
        
    # Compare last element
    if fib1 and arr[offset + 1] == k:
        return offset + 1
        
    # Element not found
    return -1


arr = [1,2,3,4,6,7,8,9]
k = 2
n = len(arr)

result = fibonacciSearch(arr, k)
if result != -1:
    print(f"Element {k} found at index {result}")
else:
    print(f"Element {k} not found in array")

 
    
arr = [1,2,3,4,6,7,8,9]
k = 2
n = len(arr)


# sentinelSearch(arr, k)
# print(fibonacciSearch(arr, k))

def sorted(arr, n):
    for i in range(n - 1):
        if arr[i] > arr[i + 1]:
            return False
    return True

# if sorted(arr, n):
#     m = binary(arr, k, 0, n -1)
#     print("The data is sorted")
#     if m == -1:
#         print("NF")
#     else:
#         print("F ", arr[m])
# else:
#     print("Plz enter sorted data for appropriate results")
# Out:
# Element 2 found at index 1

# %%
def fibonnaci (arr, k):
    n = len(arr)
    fib2 = 0
    fib1 = 1
    fib = fib1 + fib2
    
    while (fib < n) :
        fib2 = fib1
        fib1 = fib 
        fib = fib1 + fib2
        
    offset = -1
    
    while fib > 1:
        i = min(offset + fib2, n - 1)
        
        if arr[i] < k:
            fib = fib1
            fib1 = fib2
            fib2 = fib - fib1
            offset = i
            
        elif arr[i] > k:
            fib = fib2 
            fib1 = fib1 - fib2
            fib2 = fib - fib1
            
        else:
            return i
        
    if fib1 and arr[offset + 1] == k:
        return offset + 1
    
    return -1

arr = [1,2,3,4,6,7,8,9]
k = 10
n = len(arr)

result = fibonacciSearch(arr, k)
if result != -1:
    print(f"Element {k} found at index {result}")
else:
    print(f"Element {k} not found in array")
# Out:
# Element 10 not found in array

# %%
# KR
# ASsignment 5

# Write a Python program to store first year percentage of students in array. Write
# function for sorting array of floating point numbers in ascending order using quick sort
# and display top five scores

def quick(arr, low, high):
    if low < high:
        pvt = partition(arr, low , high)
        quick(arr, low, pvt - 1)
        quick(arr, pvt + 1, high)
    
def partition (arr, low , high):    
    pivot = arr[high]
    
    i = low - 1
    
    for j in range(low, high):
        if arr[j] < pivot:
            i += 1
            arr[j], arr[i] = arr[i], arr[j]
            
    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    
    return i + 1

arr = [2, 0, 3, 1, 10, 5, 7, 4]
low = 0
n = len(arr)
quick(arr, 0, n -1)
print(arr)
# Out:
# [0, 1, 2, 3, 4, 5, 7, 10]
